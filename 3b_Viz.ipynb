# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.io import visualize_patch_sample_directory

# %%
input_dir_path = 'dataset_samples_npz/T001-000054-IW1__2024-06-14__25/'

# %%
fig = visualize_patch_sample_directory(input_dir_path, max_pre_images=5)
