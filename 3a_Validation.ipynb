# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.io import write_tiff_from_patch_directory

# %%
input_dir_path = 'dataset_samples_npz/T001-000054-IW1__2024-06-14__25/'
output_dir_path = 'test_tiff_patch'

# %%
write_tiff_from_patch_directory(input_dir_path, output_dir_path)
# Out:
# PosixPath('test_tiff_patch/T001-000054-IW1__2024-06-14__25')
